# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utility import *
from tools import *
from maps import *
from scipy.stats import linregress
from scipy.ndimage import maximum_filter, binary_dilation
from scipy.spatial.distance import cdist

# %%
# Load the Data's directory.
datadir = 'C:/Users/txu245/Desktop/26-02-17/Add/02_01_03.zda'

# Load the Tool Packages.
DataLoader = DataLoader(datadir)
Tools = Tools()
Maps = Maps()

# %%
# Parameters setting up.
index = np.linspace(0, 499.5, 1000)
basePt = 190
skipPt = 60
startPt = 190
numPt = 40

# Data Preprocessing.
Data = DataLoader.get_data()
Data = Tools.Polynomial(startPt=basePt, numPt=skipPt, Data=Data)
Rli = DataLoader.get_rli()
Data = Tools.Rli_Division(Rli=Rli, Data=Data)
Data = Tools.T_filter(Data=Data)
Data = Tools.S_filter(sigma=1, Data=Data)
Data_ave = np.mean(Data, axis=0)

# SNR Map. (Without Normalization)
snr_map = np.zeros((80, 80))

for i in range(80):
    for j in range(80):
        SD = np.std(Data_ave[i, j, 10:60], ddof=1)
        MaxAmp = np.max(Data_ave[i, j, startPt:(startPt+numPt)])
        SNR = MaxAmp / SD
        snr_map[i][j] = SNR

# %%
# Calculate the cutoff.
values = snr_map.flatten()
cutoff = np.percentile(values, 97.5)

# Find the local maximum.
def find_local_maxima_3x3(snr_map):
    h, w = snr_map.shape
    candidates = []

    for r in range(1, h-1):
        for c in range(1, w-1):
            window = snr_map[r-1:r+2, c-1:c+2]
            center = snr_map[r, c]

            if center == np.max(window) and np.sum(window == center) == 1 and center >= cutoff:
                candidates.append([r, c, snr_map[r, c]])

    return candidates

# Select those 3x3 areas without overlapping.
def select_non_overlapping(candidates, snr_map):
    candidates = sorted(candidates, key=lambda x: x[2], reverse=True)

    selected = []
    occupied = np.zeros_like(snr_map, dtype=bool)

    for r, c, snr_value in candidates:
        if not np.any(occupied[r-1:r+2, c-1:c+2]):
            selected.append([r, c])
            occupied[r-1:r+2, c-1:c+2] = True

    return selected

# Implement.
candidates = find_local_maxima_3x3(snr_map)
selected = select_non_overlapping(candidates, snr_map)
identified_map = np.zeros_like(snr_map, dtype=int)

for coor in selected:
    identified_map[coor[0]][coor[1]] = 1

# %%
# Plotting.
linewidth = 1.5
color = 'red'

index = np.where(identified_map == 1)
index = np.transpose(index, (1, 0))

fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(snr_map / np.max(snr_map), cmap=Maps.colorbar())

for i, coor in enumerate(index):

    #  Coordinates for columns and rows.   
    c = coor[0]
    r = coor[1]

    # Pixel boundaries.
    left   = c - 1.5
    right  = c + 1.5
    top    = r - 1.5
    bottom = r + 1.5

    # Draw square contour.
    ax.plot([top, top], [left, right], color=color, linewidth=linewidth)
    ax.plot([bottom, bottom], [left, right], color=color, linewidth=linewidth)
    ax.plot([top, bottom], [left, left], color=color, linewidth=linewidth)
    ax.plot([top, bottom], [right, right], color=color, linewidth=linewidth)

    # Label index.
    ax.annotate(str(i+1), xy=(r, c), ha='center', va='center', fontsize=7, color='black')

plt.show()

# %%
num = len(index)
trial = Data.shape[0]
latency = np.zeros((num, trial))
count = 0

fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(snr_map / np.max(snr_map), cmap=Maps.colorbar())

for i, coor in enumerate(index):

    #  Coordinates for columns and rows.   
    c = coor[0]
    r = coor[1]

    # Pixel boundaries.
    left   = c - 1.5
    right  = c + 1.5
    top    = r - 1.5
    bottom = r + 1.5

    # Draw square contour.
    ax.plot([top, top], [left, right], color=color, linewidth=linewidth)
    ax.plot([bottom, bottom], [left, right], color=color, linewidth=linewidth)
    ax.plot([top, bottom], [left, left], color=color, linewidth=linewidth)
    ax.plot([top, bottom], [right, right], color=color, linewidth=linewidth)

    # Label index.
    ax.annotate(str(i+1), xy=(r, c), ha='center', va='center', fontsize=7, color='black')

for i in range(num):
    for j in range(trial):

        Trace = np.mean(Data[j, index[i][0]-1:index[i][0]+2, index[i][1]-1:index[i][1]+2, :], axis=(0, 1))
        latency[i][j] = Maps.Half_Amp_Latency(Trace=Trace, startPt=startPt, numPt=numPt)

for i in range(num-1):
    for j in range(i+1, num):
        
        dist = np.sqrt((index[i][0] - index[j][0])**2 + (index[i][1] - index[j][1])**2) * 6
        Slope, _, _, pValue, _ = linregress(latency[i], latency[j])
        if pValue <=0.05 and Slope > 0:
            count = count + 1
            print('Neuron', i+1, 'and Neuron', j+1, 'are correlated with a positive slope, and the P-Value is:', np.round(pValue, 6), ', distance is:', dist, 'um.')
            loc_1 = index[i]
            loc_2 = index[j]

            ax.plot([loc_1[1], loc_2[1]], [loc_1[0], loc_2[0]], color='red', linewidth=1)

plt.show()

print(count, 'pairs are correlated.')
print('Totally', int(num*(num-1)/2), 'pairs.')
# Out:
# Neuron 1 and Neuron 51 are correlated with a positive slope, and the P-Value is: 0.036621 , distance is: 216.0833172644293 um.
# Neuron 2 and Neuron 7 are correlated with a positive slope, and the P-Value is: 1e-05 , distance is: 18.973665961010276 um.
# Neuron 2 and Neuron 14 are correlated with a positive slope, and the P-Value is: 0.002053 , distance is: 36.49657518178932 um.
# Neuron 2 and Neuron 18 are correlated with a positive slope, and the P-Value is: 0.043366 , distance is: 148.18906842274163 um.
# Neuron 2 and Neuron 27 are correlated with a positive slope, and the P-Value is: 0.007374 , distance is: 85.90692637965812 um.
# Neuron 2 and Neuron 34 are correlated with a positive slope, and the P-Value is: 0.021825 , distance is: 112.72976536833562 um.
# Neuron 2 and Neuron 47 are correlated with a positive slope, and the P-Value is: 4e-05 , distance is: 176.56726763474592 um.
# Neuron 2 and Neuron 52 are correlated with a positive slope, and the P-Value is: 0.000139 , distance is: 314.3564855383137 um.
# Neuron 2 and Neuron 54 are correlated with a positive slope, and the P-Value is: 0.000566 , distance is: 358.0949594730426 um.
# Neuron 3 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.016159 , distance is: 172.75416058665562 um.
# Neuron 3 and Neuron 51 are correlated with a positive slope, and the P-Value is: 0.045998 , distance is: 238.8723508487326 um.
# Neuron 4 and Neuron 30 are correlated with a positive slope, and the P-Value is: 0.001498 , distance is: 171.81385275931623 um.
# Neuron 5 and Neuron 9 are correlated with a positive slope, and the P-Value is: 0.029793 , distance is: 108.0 um.
# Neuron 5 and Neuron 21 are correlated with a positive slope, and the P-Value is: 0.000218 , distance is: 127.13772060250255 um.
# Neuron 5 and Neuron 32 are correlated with a positive slope, and the P-Value is: 0.00864 , distance is: 216.33307652783935 um.
# Neuron 5 and Neuron 45 are correlated with a positive slope, and the P-Value is: 0.004954 , distance is: 144.12494579357175 um.
# Neuron 5 and Neuron 53 are correlated with a positive slope, and the P-Value is: 0.008377 , distance is: 298.3756022197525 um.
# Neuron 6 and Neuron 16 are correlated with a positive slope, and the P-Value is: 0.040325 , distance is: 34.98571136907181 um.
# Neuron 7 and Neuron 12 are correlated with a positive slope, and the P-Value is: 0.032226 , distance is: 61.188234163113414 um.
# Neuron 7 and Neuron 14 are correlated with a positive slope, and the P-Value is: 0.011016 , distance is: 21.633307652783934 um.
# Neuron 7 and Neuron 27 are correlated with a positive slope, and the P-Value is: 0.01237 , distance is: 73.2393336944022 um.
# Neuron 7 and Neuron 31 are correlated with a positive slope, and the P-Value is: 0.014486 , distance is: 115.25623627379127 um.
# Neuron 7 and Neuron 34 are correlated with a positive slope, and the P-Value is: 0.01052 , distance is: 93.91485505499116 um.
# Neuron 7 and Neuron 47 are correlated with a positive slope, and the P-Value is: 0.000737 , distance is: 160.099968769516 um.
# Neuron 7 and Neuron 52 are correlated with a positive slope, and the P-Value is: 0.000589 , distance is: 295.4657340538831 um.
# Neuron 7 and Neuron 54 are correlated with a positive slope, and the P-Value is: 1e-06 , distance is: 339.4112549695428 um.
# Neuron 9 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.035405 , distance is: 150.0 um.
# Neuron 9 and Neuron 49 are correlated with a positive slope, and the P-Value is: 0.000201 , distance is: 175.64737401965337 um.
# Neuron 10 and Neuron 22 are correlated with a positive slope, and the P-Value is: 0.021083 , distance is: 197.9090700296477 um.
# Neuron 11 and Neuron 28 are correlated with a positive slope, and the P-Value is: 0.01596 , distance is: 89.19641248391103 um.
# Neuron 11 and Neuron 45 are correlated with a positive slope, and the P-Value is: 0.047333 , distance is: 290.24127893874777 um.
# Neuron 13 and Neuron 25 are correlated with a positive slope, and the P-Value is: 0.018754 , distance is: 150.0 um.
# Neuron 13 and Neuron 29 are correlated with a positive slope, and the P-Value is: 2.9e-05 , distance is: 110.14535850411491 um.
# Neuron 13 and Neuron 42 are correlated with a positive slope, and the P-Value is: 0.015313 , distance is: 104.78549517943787 um.
# Neuron 14 and Neuron 27 are correlated with a positive slope, and the P-Value is: 0.019328 , distance is: 51.61395160225576 um.
# Neuron 14 and Neuron 52 are correlated with a positive slope, and the P-Value is: 0.035536 , distance is: 281.04092228712886 um.
# Neuron 17 and Neuron 22 are correlated with a positive slope, and the P-Value is: 0.004947 , distance is: 84.8528137423857 um.
# Neuron 19 and Neuron 40 are correlated with a positive slope, and the P-Value is: 0.005384 , distance is: 93.72299611087985 um.
# Neuron 20 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.007722 , distance is: 103.5760590097924 um.
# Neuron 21 and Neuron 48 are correlated with a positive slope, and the P-Value is: 0.02026 , distance is: 157.49285698088025 um.
# Neuron 21 and Neuron 53 are correlated with a positive slope, and the P-Value is: 0.04594 , distance is: 249.55961211702507 um.
# Neuron 22 and Neuron 31 are correlated with a positive slope, and the P-Value is: 0.021131 , distance is: 175.64737401965337 um.
# Neuron 22 and Neuron 33 are correlated with a positive slope, and the P-Value is: 0.030547 , distance is: 129.52219886953742 um.
# Neuron 22 and Neuron 37 are correlated with a positive slope, and the P-Value is: 0.02029 , distance is: 99.85990186255944 um.
# Neuron 22 and Neuron 56 are correlated with a positive slope, and the P-Value is: 0.029781 , distance is: 327.42632759141406 um.
# Neuron 23 and Neuron 39 are correlated with a positive slope, and the P-Value is: 0.014764 , distance is: 134.1640786499874 um.
# Neuron 24 and Neuron 38 are correlated with a positive slope, and the P-Value is: 0.007736 , distance is: 61.773780845922005 um.
# Neuron 24 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.020745 , distance is: 188.30825791770258 um.
# Neuron 25 and Neuron 29 are correlated with a positive slope, and the P-Value is: 0.040066 , distance is: 49.47726750741192 um.
# Neuron 28 and Neuron 36 are correlated with a positive slope, and the P-Value is: 0.042191 , distance is: 135.36617007214173 um.
# Neuron 30 and Neuron 38 are correlated with a positive slope, and the P-Value is: 0.032353 , distance is: 131.04197800704932 um.
# Neuron 30 and Neuron 40 are correlated with a positive slope, and the P-Value is: 0.004348 , distance is: 151.7893276880822 um.
# Neuron 31 and Neuron 32 are correlated with a positive slope, and the P-Value is: 0.019781 , distance is: 48.0 um.
# Neuron 31 and Neuron 47 are correlated with a positive slope, and the P-Value is: 0.029672 , distance is: 99.85990186255944 um.
# Neuron 31 and Neuron 54 are correlated with a positive slope, and the P-Value is: 0.049637 , distance is: 297.89259809535383 um.
# Neuron 31 and Neuron 56 are correlated with a positive slope, and the P-Value is: 0.033792 , distance is: 309.2765752526369 um.
# Neuron 32 and Neuron 35 are correlated with a positive slope, and the P-Value is: 0.000645 , distance is: 228.70942263055102 um.
# Neuron 32 and Neuron 45 are correlated with a positive slope, and the P-Value is: 0.001975 , distance is: 222.0 um.
# Neuron 33 and Neuron 43 are correlated with a positive slope, and the P-Value is: 7e-06 , distance is: 86.53323061113574 um.
# Neuron 33 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.010828 , distance is: 78.2304288624318 um.
# Neuron 35 and Neuron 45 are correlated with a positive slope, and the P-Value is: 0.022461 , distance is: 56.92099788303083 um.
# Neuron 42 and Neuron 50 are correlated with a positive slope, and the P-Value is: 0.032723 , distance is: 111.60645142642966 um.
# Neuron 43 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.016895 , distance is: 34.98571136907181 um.
# Neuron 45 and Neuron 53 are correlated with a positive slope, and the P-Value is: 0.049014 , distance is: 166.70932787339765 um.
# Neuron 46 and Neuron 49 are correlated with a positive slope, and the P-Value is: 0.007084 , distance is: 72.49827584156743 um.
# Neuron 47 and Neuron 52 are correlated with a positive slope, and the P-Value is: 0.000157 , distance is: 166.81726529349413 um.
# Neuron 47 and Neuron 54 are correlated with a positive slope, and the P-Value is: 0.001581 , distance is: 198.63534428696218 um.
# Neuron 52 and Neuron 54 are correlated with a positive slope, and the P-Value is: 0.000153 , distance is: 51.26402247190518 um.
# 68 pairs are correlated.
# Totally 1596 pairs.

# %%
neuro_label = 3

fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(snr_map / np.max(snr_map), cmap=Maps.colorbar())
top = index[neuro_label-1][1] - 1.5
bottom = index[neuro_label-1][1] + 1.5
left = index[neuro_label-1][0] - 1.5
right = index[neuro_label-1][0] + 1.5

ax.plot([top, top], [left, right], color=color, linewidth=linewidth)
ax.plot([bottom, bottom], [left, right], color=color, linewidth=linewidth)
ax.plot([top, bottom], [left, left], color=color, linewidth=linewidth)
ax.plot([top, bottom], [right, right], color=color, linewidth=linewidth)
ax.annotate(str(neuro_label), xy=(index[neuro_label-1][1], index[neuro_label-1][0]), ha='center', va='center', fontsize=7, color='black')

for i in range(num):

    if i == neuro_label - 1:
        continue
    else:
        dist = np.sqrt((index[i][0] - index[neuro_label-1][0])**2 + (index[i][1] - index[neuro_label-1][1])**2) * 6
        Slope, _, _, pValue, _ = linregress(latency[i], latency[neuro_label-1])

        if pValue <=0.05 and Slope > 0:
            count = count + 1
            print('Neuron', neuro_label, 'and Neuron', i+1, 'are correlated with a positive slope, and the P-Value is:', np.round(pValue, 6), ', distance is:', dist, 'um.')
            loc_1 = index[i]
            loc_2 = index[neuro_label-1]

            ax.plot([loc_1[1], loc_2[1]], [loc_1[0], loc_2[0]], color='red', linewidth=1)

            top = loc_1[1] - 1.5
            bottom = loc_1[1] + 1.5
            left = loc_1[0] - 1.5
            right = loc_1[0] + 1.5

            ax.plot([top, top], [left, right], color=color, linewidth=linewidth)
            ax.plot([bottom, bottom], [left, right], color=color, linewidth=linewidth)
            ax.plot([top, bottom], [left, left], color=color, linewidth=linewidth)
            ax.plot([top, bottom], [right, right], color=color, linewidth=linewidth)
            ax.annotate(str(i+1), xy=(loc_1[1], loc_1[0]), ha='center', va='center', fontsize=7, color='black')

plt.show()
# Out:
# Neuron 3 and Neuron 46 are correlated with a positive slope, and the P-Value is: 0.016159 , distance is: 172.75416058665562 um.
# Neuron 3 and Neuron 51 are correlated with a positive slope, and the P-Value is: 0.045998 , distance is: 238.8723508487326 um.

# %%
index[2]
# Out:
# array([ 3, 46])
