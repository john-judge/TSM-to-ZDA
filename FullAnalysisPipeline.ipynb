# %%
import time
import os
import math
import numpy as np
import cv2
import pandas as pd
import pyautogui as pa
import shutil
import imageio
from PIL import Image, ImageDraw

from lib.auto_GUI.auto_GUI_base import AutoGUIBase
from lib.auto_GUI.auto_DAT import AutoDAT
from lib.auto_GUI.auto_PhotoZ import AutoPhotoZ
from lib.analysis.laminar_dist import *
from lib.file.TIF import *
from lib.analysis.align import ImageAlign
from lib.utilities import *

# %%
# Make a series of 1-frame measure windows from PhotoZ

# Load data, not from Drive for Desktop since PhotoZ complains about loading zda from Drive
google_drive_dir = "G:/.shortcut-targets-by-id/1afwzLrN3AQQPbJ1PQiZlKAb1Bijc5qln/Choosing trajectories/"
data_dir = "C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/"
start_frame = 94
movie_length = 27
camera_program = 4

# annotation settings
skip_draw_annotations = False  # don't draw any new annotations

# Movie maker settings
disable_photoZ_interact = False
disable_google_drive_interact = True
initialize_photoZ = False
clean_scratch_files = False  # clean up SNR maps
replace_existing_frame_pngs = True
image_border_width = 8
image_scaling = 7  # pixels of image per array diode pixel
electrode_marker_radius = 4

# %%
# set up PhotoZ (open it manually)
aPhz = AutoPhotoZ(data_dir=data_dir)
if initialize_photoZ and not disable_photoZ_interact:
    aPhz.prepare_photoZ()
if not disable_photoZ_interact:
    aPhz.click_normalize_2_array_max()
pa.alert("Please disable trace overlay and maximize PhotoZ before continuing.")
# Out:
# 'OK'

# %%
# First ask user to annotate some images with Electrode loc and L4 boundaries and layer text placement
# based on DIC-to-ZDA_Alignment script
if not skip_draw_annotations:
    for subdir, dirs, files in os.walk(data_dir):
        if 'notUsable' in subdir:
            continue
        if 'mm_hidden' in subdir:
            continue
        if 'dic' in dirs and 'selected_zda' in dirs:
            dic_dir = subdir + "/dic/"
            selected_zda_dir = subdir + "/selected_zda/"
            already_drawn_slic_loc = {}

            # take selected zda and expand into separate subdir for each zda file
            for zda_file in os.listdir(selected_zda_dir):
                if zda_file.endswith('.zda'):
                    rec_id = zda_file.split('.')[0]
                    slic_id, loc_id, _ = [int(x) for x in rec_id.split("_")]
                    print(rec_id)
                    # output dir
                    output_dir = selected_zda_dir + "/analysis" + rec_id + "/"
                    try:
                        os.makedirs(output_dir)
                    except Exception as e:
                        pass

                    # read in 8-bit single TIF images to array, apply same cropping/binning
                    image_data = {}
                    cam_settings = CameraSettings().get_program_settings(camera_program)
                    binning = int(2048 / 400) # if want size similar to RLI
                    TIFLoader(dic_dir, 
                              cam_settings, 
                              binning, 
                              crop=False, 
                              flip_horiz=True).load_files(image_data, slice_target=slic_id)

                    # align RLI and DIC and record the RLI's image boundaries within the DIC image.
                    dic_coordinates = [[8, 6], [80, 12], [2, 69], [76, 74]]
                    img_aligner = ImageAlign(dic_coordinates)

                    for slic in image_data:
                        for loc in image_data[slic]:

                            if slic != slic_id or loc != loc_id:
                                continue

                            # if already drawn, no need to ask user again
                            if str(slic_id)+"_"+str(loc_id) in already_drawn_slic_loc:
                                # just copy them over
                                src_dir = already_drawn_slic_loc[str(slic_id)+"_"+str(loc_id)]
                                electrode_file = src_dir + "electrode.dat"
                                corners_layer_file = src_dir + "corners_layer.dat"
                                corners_barrel_file = src_dir + "corners_barrel.dat"
                                shutil.copy(electrode_file, output_dir + "electrode.dat")
                                shutil.copy(corners_layer_file, output_dir + "corners_layer.dat")
                                shutil.copy(corners_barrel_file, output_dir + "corners_barrel.dat")
                                continue

                            print(slic, loc)

                            # DICs
                            fluor = None
                            if 'f' in image_data[slic][loc]:
                                fluor = image_data[slic][loc]['f']
                            elif 'fe' in image_data[slic][loc]:
                                fluor = image_data[slic][loc]['fe']
                            # img = image_data[slic][loc]['i']

                            dic_electrode = None
                            if 'e' in image_data[slic][loc]:
                                dic_electrode = image_data[slic][loc]['e']
                            else:
                                dic_electrode = fluor

                            dic_electrode = np.array(dic_electrode, dtype=np.uint8)
                            orig_arr_shape = dic_electrode.shape

                            # ask user to select site of stim and layer/barrel borders
                            dic_electrode, coords_electrode, dic_layers, coords_layers = img_aligner.draw_on_images_wrapper(dic_electrode, fluor)
                            dic_electrode = np.array(dic_electrode)
                            dic_layers = np.array(dic_layers)

                            plt.imshow(dic_electrode, cmap='gray')
                            x_el, y_el = coords_electrode['electrode']
                            plt.plot(x_el, y_el, marker="*", color='red')
                            plt.show()
                            
                            plt.imshow(dic_layers, cmap='gray')
                            for pt in coords_layers['layer_axis1'] + coords_layers['layer_axis2'] + coords_layers['barrel_axis1'] + coords_layers['barrel_axis2']:
                                x, y = pt
                                plt.plot(x, y, marker="*", color='green')
                            plt.show()

                            try:
                                os.makedirs(output_dir)
                            except OSError:
                                pass

                            # transform coordinates -- Actual alignment work done here
                            coords_electrode = img_aligner.transform_from_dic_coordinates(coords_electrode, orig_arr_shape)
                            coords_layers = img_aligner.transform_from_dic_coordinates(coords_layers, orig_arr_shape)
                            coordinates = coords_electrode | coords_layers

                            # write to file
                            electrode_file = output_dir + "electrode.dat"
                            corners_layer_file = output_dir + "corners_layer.dat"
                            corners_barrel_file = output_dir + "corners_barrel.dat"
                            img_aligner.write_shapes_to_files(coordinates,
                                                              electrode_file,
                                                              corners_layer_file,
                                                              corners_barrel_file)
                            print("Wrote files to", output_dir)

                            # mark this slice/loc already drawn 
                            already_drawn_slic_loc[str(slic_id)+"_"+str(loc_id)] = output_dir
                    image_data.clear()
# Out:
# 02_01_01
# 2 1
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [59, 48]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/
# 02_01_03
# 02_02_02
# 2 2
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [48, 67]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/
# 03_01_01
# 3 1
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [63, 28]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/
# 03_02_01
# 3 2
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [62, 46]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/
# 03_02_02
# 03_02_12
# 06_01_01
# 6 1
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [52, 23]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/
# 06_01_03
# 06_01_06
# 02_02_02
# 2 2
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [36, 70]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/
# 02_03_05
# 2 3
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [9, 68]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/
# 02_03_08

# %%
current_color_bound_setting = 1.0
for subdir, dirs, files in os.walk(data_dir):
    if 'notUsable' in subdir:
        continue
    if 'mm_hidden' in subdir:
        continue
    if 'dic' in dirs and 'selected_zda' in dirs:
        print(subdir)
        dic_dir = subdir + "/dic/"
        selected_zda_dir = subdir + "/selected_zda/"

        for zda_file in os.listdir(selected_zda_dir):
            if zda_file.endswith('.zda'):

                rec_id = zda_file.split('.')[0]
                print(rec_id)
                # movie dir
                output_dir = selected_zda_dir + "/analysis" + rec_id + "/"
                try:
                    os.makedirs(output_dir)
                except Exception as e:
                    pass

                # determine if we are even missing any jpg'd frames
                need_to_open_zda = True
                for frame in range(start_frame, start_frame + movie_length):
                    filename = output_dir + str(frame) + ".jpg"
                    if not os.path.exists(filename):
                        need_to_open_zda = True
                        break
                if not need_to_open_zda and not replace_existing_frame_pngs:
                    continue

                recording_max_snr = 20.0  # gets changed

                if not disable_photoZ_interact:
                    aPhz = AutoPhotoZ(data_dir=selected_zda_dir)
                    # open the PhotoZ file
                    aPhz.select_PhotoZ()

                    print("\n\nOpening", zda_file)
                    aPhz.open_zda_file(selected_zda_dir + "/" + zda_file)

                    # estimate the SNR max across all frames
                    aPhz.set_measure_window(start_frame, movie_length)
                    filename = aPhz.save_background()
                    print("Saved intermed_snr_df file:", filename)
                    if filename is not None:  # otherwise, sticks with default rec max of 20

                        # open Data.dat and read in the array max
                        intermed_snr_df = pd.read_csv(filename, 
                                                      sep='\t', 
                                                      header=None, 
                                                      names=['Index',  'Values'])
                        recording_max_snr = intermed_snr_df['Values'].max()

                        recording_max_snr *= 1.05  # 5% higher for headroom
                        recording_max_snr = round(recording_max_snr, 2)
                        if clean_scratch_files:
                            try:
                                os.remove(filename)
                            except Exception as e:
                                print("Could not remove", filename)
                                print(e)

                    # set the normalization to be consistent across entire video
                    aPhz.set_color_upper_bound(recording_max_snr, current_color_bound_setting)
                    print("Moved color upper bound from", current_color_bound_setting, "to", recording_max_snr)
                    current_color_bound_setting = recording_max_snr

                    # set measure window width to 1
                    aPhz.set_measure_window(None, 1)

                ##### Get frame annotation: layer and stim markings, and store #####

                # file conventions across
                electrode_file = output_dir + "/electrode.dat"
                corners_layer_file = output_dir + "/corners_layer.dat"
                corners_barrel_file = output_dir + "/corners_barrel.dat"
                annotations_enabled = all([os.path.exists(f) for f in [electrode_file, 
                                                                       corners_layer_file, 
                                                                       corners_barrel_file]])

                def array_point_to_image_pixel(arr_pt):
                    x_arr, y_arr = arr_pt
                    return [image_border_width + image_scaling * x_arr, 
                            image_border_width + image_scaling * y_arr]

                if annotations_enabled:
                    # read in electrode location
                    with open(electrode_file, 'r') as f:
                        lines = f.readlines()
                    stim_pt = int(lines[-1]) # last line is always electrode location
                    aux_obj = LaminarROI([stim_pt]).get_points()
                    stim_pt = aux_obj[0]  # should be a list of len 2, representing px location [x, y]
                    print("Stim point:", stim_pt)
                    stim_img_px = array_point_to_image_pixel(stim_pt)
                    stim_xy = (stim_img_px[0] - electrode_marker_radius, 
                               stim_img_px[1] - electrode_marker_radius, 
                               stim_img_px[0] + electrode_marker_radius, 
                               stim_img_px[1] + electrode_marker_radius)
                    # read in corners files
                    la_corners = {corners_layer_file: {},
                                  corners_barrel_file: {}}
                    for la_file in [corners_layer_file, corners_barrel_file]:
                        with open(la_file, 'r') as f:
                            lines = f.readlines() 
                        corners = [int(x) for x in lines[4:]] # the last 4 lines are diode numbers of corners
                        layer_axes = LayerAxes(corners)
                        laminar_axis, laminar_axis_2 = layer_axes.get_layer_axes()
                        print("laminar axis unit vectors:", laminar_axis.get_unit_vector(), 
                              laminar_axis_2.get_unit_vector())

                        end = array_point_to_image_pixel(laminar_axis.get_end_point())
                        end2 = array_point_to_image_pixel(laminar_axis_2.get_end_point())
                        start = array_point_to_image_pixel(laminar_axis.get_start_point())
                        start2 = array_point_to_image_pixel(laminar_axis_2.get_start_point())
                        la_corners[la_file]["line_loc"] = [start + end, start2 + end2]
                        la_corners[la_file]["text_loc"] = (int((end[0] + end2[0]) / 2), 
                                                           int((end[1] + end2[1]) / 2))


                images = []
                img_filenames = []
                for frame in range(start_frame, start_frame + movie_length):
                    filename = output_dir + str(frame) + ".jpg"
                    if replace_existing_frame_pngs or not os.path.exists(filename):
                        # change frame
                        if not disable_photoZ_interact:
                            aPhz.set_measure_window(frame, None)

                            # export this frame
                            aPhz.save_map_jpeg(filename)
                            print("File created:", filename)

                    if annotations_enabled:
                        # draw electrode location on image <filename>
                        image = Image.open(filename)
                        draw = ImageDraw.Draw(image)
                        draw.ellipse(stim_xy, outline='red', width=2)
                        # read in corners files
                        for la_file in [corners_layer_file, corners_barrel_file]:
                            draw.line(la_corners[la_file]["line_loc"][0], fill='white', width=2)
                            draw.line(la_corners[la_file]["line_loc"][1], fill='white', width=2)
                            if la_file == corners_layer_file:
                                draw.text(la_corners[la_file]["text_loc"], "L4", anchor="ms")
                        # PIL image write back
                        image.save(filename)

                    try:
                        images.append(imageio.imread(filename))
                        img_filenames.append(filename)
                    except Exception as e:
                        pass

                # create gif
                created_movie = False
                try:
                    imageio.mimsave(output_dir + rec_id + 'movie.gif', images)
                    print("CREATED MOVIE:", rec_id + 'movie.gif')
                    created_movie = True
                    if clean_scratch_files:
                        for img_file in img_filenames:
                            os.remove(img_file)
                except Exception as e:
                    if not created_movie:
                        print("Not creating movie for " + rec_id)
                    print(e)
# Out:
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23
# 02_01_01
#
#
# Opening 02_01_01.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 1.0 to 13.06
# Stim point: [59, 48]
# edge_pts [[8, 69], [37, 71]] axis_pts [[44, 10], [77, 17]]
# laminar axis unit vectors: [-0.5208646456291304, 0.8536392803366304] [-0.5952275506257376, 0.8035571933447457]
# edge_pts [[10, 7], [6, 42]] axis_pts [[74, 31], [68, 63]]
# laminar axis unit vectors: [-0.9363291775690445, -0.3511234415883917] [-0.9471445756278132, -0.3208070336803883]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_01/120.jpg
# CREATED MOVIE: 02_01_01movie.gif
# 02_01_03
#
#
# Opening 02_01_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 13.06 to 13.06
# Stim point: [59, 48]
# edge_pts [[8, 69], [37, 71]] axis_pts [[44, 10], [77, 17]]
# laminar axis unit vectors: [-0.5208646456291304, 0.8536392803366304] [-0.5952275506257376, 0.8035571933447457]
# edge_pts [[10, 7], [6, 42]] axis_pts [[74, 31], [68, 63]]
# laminar axis unit vectors: [-0.9363291775690445, -0.3511234415883917] [-0.9471445756278132, -0.3208070336803883]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_01_03/120.jpg
# CREATED MOVIE: 02_01_03movie.gif
# 02_02_02
#
#
# Opening 02_02_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 13.06 to 9.54
# Stim point: [48, 67]
# edge_pts [[39, 70], [8, 68]] axis_pts [[72, 15], [44, 10]]
# laminar axis unit vectors: [-0.5144957554275266, 0.8574929257125442] [-0.5273628617781428, 0.8496401661981191]
# edge_pts [[8, 54], [9, 12]] axis_pts [[67, 69], [73, 37]]
# laminar axis unit vectors: [-0.9691685310936223, -0.24639877909159888] [-0.9314573494796193, -0.3638505271404763]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis02_02_02/120.jpg
# CREATED MOVIE: 02_02_02movie.gif
# 03_01_01
#
#
# Opening 03_01_01.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 9.54 to 9.54
# Stim point: [63, 28]
# edge_pts [[18, 69], [48, 72]] axis_pts [[26, 9], [56, 11]]
# laminar axis unit vectors: [-0.13216372009101796, 0.9912279006826347] [-0.13003403680018621, 0.9915095306014198]
# edge_pts [[4, 56], [10, 20]] axis_pts [[70, 63], [74, 25]]
# laminar axis unit vectors: [-0.9944225846982772, -0.10546906201345364] [-0.9969621413492434, -0.07788766729290965]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_01_01/120.jpg
# CREATED MOVIE: 03_01_01movie.gif
# 03_02_01
#
#
# Opening 03_02_01.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 9.54 to 9.54
# Stim point: [62, 46]
# edge_pts [[18, 70], [53, 72]] axis_pts [[23, 8], [52, 11]]
# laminar axis unit vectors: [-0.08038418992031009, 0.996763955011845] [0.01639124023930107, 0.9998656545973652]
# edge_pts [[8, 18], [6, 54]] axis_pts [[76, 26], [70, 62]]
# laminar axis unit vectors: [-0.9931506043228762, -0.1168412475673972] [-0.9922778767136677, -0.12403473458920847]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_01/120.jpg
# CREATED MOVIE: 03_02_01movie.gif
# 03_02_02
#
#
# Opening 03_02_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 9.54 to 9.54
# Stim point: [62, 46]
# edge_pts [[18, 70], [53, 72]] axis_pts [[23, 8], [52, 11]]
# laminar axis unit vectors: [-0.08038418992031009, 0.996763955011845] [0.01639124023930107, 0.9998656545973652]
# edge_pts [[8, 18], [6, 54]] axis_pts [[76, 26], [70, 62]]
# laminar axis unit vectors: [-0.9931506043228762, -0.1168412475673972] [-0.9922778767136677, -0.12403473458920847]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_02/120.jpg
# CREATED MOVIE: 03_02_02movie.gif
# 03_02_12
#
#
# Opening 03_02_12.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 9.54 to 9.54
# Stim point: [62, 46]
# edge_pts [[18, 70], [53, 72]] axis_pts [[23, 8], [52, 11]]
# laminar axis unit vectors: [-0.08038418992031009, 0.996763955011845] [0.01639124023930107, 0.9998656545973652]
# edge_pts [[8, 18], [6, 54]] axis_pts [[76, 26], [70, 62]]
# laminar axis unit vectors: [-0.9931506043228762, -0.1168412475673972] [-0.9922778767136677, -0.12403473458920847]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis03_02_12/120.jpg
# CREATED MOVIE: 03_02_12movie.gif
# 06_01_01
#
#
# Opening 06_01_01.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 9.54 to 12.22
# Stim point: [52, 23]
# edge_pts [[4, 65], [41, 72]] axis_pts [[59, 12], [75, 35]]
# laminar axis unit vectors: [-0.7200778916462509, 0.6938932410409328] [-0.6766252893427926, 0.736327520755392]
# edge_pts [[8, 41], [8, 15]] axis_pts [[69, 61], [74, 35]]
# laminar axis unit vectors: [-0.9502295409734977, -0.3115506691716386] [-0.9570244044334736, -0.2900073952828708]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_01/120.jpg
# CREATED MOVIE: 06_01_01movie.gif
# 06_01_03
#
#
# Opening 06_01_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 12.22 to 12.22
# Stim point: [52, 23]
# edge_pts [[4, 65], [41, 72]] axis_pts [[59, 12], [75, 35]]
# laminar axis unit vectors: [-0.7200778916462509, 0.6938932410409328] [-0.6766252893427926, 0.736327520755392]
# edge_pts [[8, 41], [8, 15]] axis_pts [[69, 61], [74, 35]]
# laminar axis unit vectors: [-0.9502295409734977, -0.3115506691716386] [-0.9570244044334736, -0.2900073952828708]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_03/120.jpg
# CREATED MOVIE: 06_01_03movie.gif
# 06_01_06
#
#
# Opening 06_01_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 12.22 to 12.22
# Stim point: [52, 23]
# edge_pts [[4, 65], [41, 72]] axis_pts [[59, 12], [75, 35]]
# laminar axis unit vectors: [-0.7200778916462509, 0.6938932410409328] [-0.6766252893427926, 0.736327520755392]
# edge_pts [[8, 41], [8, 15]] axis_pts [[69, 61], [74, 35]]
# laminar axis unit vectors: [-0.9502295409734977, -0.3115506691716386] [-0.9570244044334736, -0.2900073952828708]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis06_01_06/120.jpg
# CREATED MOVIE: 06_01_06movie.gif
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23
# 02_02_02
#
#
# Opening 02_02_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//Data.dat
# Moved color upper bound from 12.22 to 15.63
# Stim point: [36, 70]
# edge_pts [[12, 14], [5, 48]] axis_pts [[73, 26], [70, 60]]
# laminar axis unit vectors: [-0.981194456491118, -0.19302186029333468] [-0.9833821803872266, -0.18154747945610336]
# edge_pts [[9, 69], [64, 73]] axis_pts [[41, 11], [70, 14]]
# laminar axis unit vectors: [-0.4830773429113347, 0.8755776840267941] [-0.10117310209735163, 0.9948688372906244]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_02_02/120.jpg
# CREATED MOVIE: 02_02_02movie.gif
# 02_03_05
#
#
# Opening 02_03_05.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//Data.dat
# Moved color upper bound from 15.63 to 13.16
# Stim point: [9, 68]
# edge_pts [[8, 17], [7, 52]] axis_pts [[74, 30], [70, 59]]
# laminar axis unit vectors: [-0.9811482730462595, -0.19325647802426324] [-0.9938837346736189, -0.11043152607484655]
# edge_pts [[32, 8], [56, 13]] axis_pts [[23, 66], [54, 69]]
# laminar axis unit vectors: [0.15333732983159673, -0.988173903359179] [0.03569153051241249, -0.9993628543475496]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_05/120.jpg
# CREATED MOVIE: 02_03_05movie.gif
# 02_03_08
#
#
# Opening 02_03_08.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//Data.dat
# Moved color upper bound from 13.16 to 14.43
# Stim point: [9, 68]
# edge_pts [[8, 17], [7, 52]] axis_pts [[74, 30], [70, 59]]
# laminar axis unit vectors: [-0.9811482730462595, -0.19325647802426324] [-0.9938837346736189, -0.11043152607484655]
# edge_pts [[32, 8], [56, 13]] axis_pts [[23, 66], [54, 69]]
# laminar axis unit vectors: [0.15333732983159673, -0.988173903359179] [0.03569153051241249, -0.9993628543475496]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23/selected_zda//analysis02_03_08/120.jpg
# CREATED MOVIE: 02_03_08movie.gif
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23
