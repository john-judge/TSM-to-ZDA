# %%
import time
import os
import math
import numpy as np
import cv2
import pandas as pd
import pyautogui as pa
import shutil
import imageio
from PIL import Image, ImageDraw

from lib.auto_GUI.auto_GUI_base import AutoGUIBase
from lib.auto_GUI.auto_DAT import AutoDAT
from lib.auto_GUI.auto_PhotoZ import AutoPhotoZ
from lib.analysis.laminar_dist import *
from lib.file.TIF import *
from lib.analysis.align import ImageAlign
from lib.utilities import *

# %%
# Make a series of 1-frame measure windows from PhotoZ

# Load data, not from Drive for Desktop since PhotoZ complains about loading zda from Drive
google_drive_dir = "G:/.shortcut-targets-by-id/1afwzLrN3AQQPbJ1PQiZlKAb1Bijc5qln/Choosing trajectories/"
data_dir = "C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/"
start_frame = 94
movie_length = 27
camera_program = 4

# annotation settings
skip_draw_annotations = False  # don't draw any new annotations

# Movie maker settings
disable_photoZ_interact = False
disable_google_drive_interact = True
initialize_photoZ = True
clean_scratch_files = False  # clean up SNR maps
replace_existing_frame_pngs = True
image_border_width = 8
image_scaling = 7  # pixels of image per array diode pixel
electrode_marker_radius = 4

# %%
# set up PhotoZ (open it manually)
aPhz = AutoPhotoZ(data_dir=data_dir)
if initialize_photoZ and not disable_photoZ_interact:
    aPhz.prepare_photoZ()
if not disable_photoZ_interact:
    aPhz.click_normalize_2_array_max()
pa.alert("Please disable trace overlay and maximize PhotoZ before continuing.")
# Out:
# 'OK'

# %%
# First ask user to annotate some images with Electrode loc and L4 boundaries and layer text placement
# based on DIC-to-ZDA_Alignment script
if not skip_draw_annotations:
    for subdir, dirs, files in os.walk(data_dir):
        if 'notUsable' in subdir:
            continue
        if 'mm_hidden' in subdir:
            continue
        if 'dic' in dirs and 'selected_zda' in dirs:
            dic_dir = subdir + "/dic/"
            selected_zda_dir = subdir + "/selected_zda/"
            already_drawn_slic_loc = {}

            # take selected zda and expand into separate subdir for each zda file
            for zda_file in os.listdir(selected_zda_dir):
                if zda_file.endswith('.zda'):
                    rec_id = zda_file.split('.')[0]
                    slic_id, loc_id, _ = [int(x) for x in rec_id.split("_")]
                    print(rec_id)
                    # output dir
                    output_dir = selected_zda_dir + "/analysis" + rec_id + "/"
                    try:
                        os.makedirs(output_dir)
                    except Exception as e:
                        pass

                    # read in 8-bit single TIF images to array, apply same cropping/binning
                    image_data = {}
                    cam_settings = CameraSettings().get_program_settings(camera_program)
                    binning = int(2048 / 400) # if want size similar to RLI
                    TIFLoader(dic_dir, 
                              cam_settings, 
                              binning, 
                              crop=False, 
                              flip_horiz=True).load_files(image_data, slice_target=slic_id)

                    # align RLI and DIC and record the RLI's image boundaries within the DIC image.
                    dic_coordinates = [[8, 6], [80, 12], [2, 69], [76, 74]]
                    img_aligner = ImageAlign(dic_coordinates)

                    for slic in image_data:
                        for loc in image_data[slic]:

                            if slic != slic_id or loc != loc_id:
                                continue

                            # if already drawn, no need to ask user again
                            if str(slic_id)+"_"+str(loc_id) in already_drawn_slic_loc:
                                # just copy them over
                                src_dir = already_drawn_slic_loc[str(slic_id)+"_"+str(loc_id)]
                                electrode_file = src_dir + "electrode.dat"
                                corners_layer_file = src_dir + "corners_layer.dat"
                                corners_barrel_file = src_dir + "corners_barrel.dat"
                                shutil.copy(electrode_file, output_dir + "electrode.dat")
                                shutil.copy(corners_layer_file, output_dir + "corners_layer.dat")
                                shutil.copy(corners_barrel_file, output_dir + "corners_barrel.dat")
                                continue

                            print(slic, loc)

                            # DICs
                            fluor = None
                            if 'f' in image_data[slic][loc]:
                                fluor = image_data[slic][loc]['f']
                            elif 'fe' in image_data[slic][loc]:
                                fluor = image_data[slic][loc]['fe']
                            # img = image_data[slic][loc]['i']

                            dic_electrode = None
                            if 'e' in image_data[slic][loc]:
                                dic_electrode = image_data[slic][loc]['e']
                            else:
                                dic_electrode = fluor

                            dic_electrode = np.array(dic_electrode, dtype=np.uint8)
                            orig_arr_shape = dic_electrode.shape

                            # ask user to select site of stim and layer/barrel borders
                            dic_electrode, coords_electrode, dic_layers, coords_layers = img_aligner.draw_on_images_wrapper(dic_electrode, fluor)
                            dic_electrode = np.array(dic_electrode)
                            dic_layers = np.array(dic_layers)

                            plt.imshow(dic_electrode, cmap='gray')
                            x_el, y_el = coords_electrode['electrode']
                            plt.plot(x_el, y_el, marker="*", color='red')
                            plt.show()
                            
                            plt.imshow(dic_layers, cmap='gray')
                            for pt in coords_layers['layer_axis1'] + coords_layers['layer_axis2'] + coords_layers['barrel_axis1'] + coords_layers['barrel_axis2']:
                                x, y = pt
                                plt.plot(x, y, marker="*", color='green')
                            plt.show()

                            try:
                                os.makedirs(output_dir)
                            except OSError:
                                pass

                            # transform coordinates -- Actual alignment work done here
                            coords_electrode = img_aligner.transform_from_dic_coordinates(coords_electrode, orig_arr_shape)
                            coords_layers = img_aligner.transform_from_dic_coordinates(coords_layers, orig_arr_shape)
                            coordinates = coords_electrode | coords_layers

                            # write to file
                            electrode_file = output_dir + "electrode.dat"
                            corners_layer_file = output_dir + "corners_layer.dat"
                            corners_barrel_file = output_dir + "corners_barrel.dat"
                            img_aligner.write_shapes_to_files(coordinates,
                                                              electrode_file,
                                                              corners_layer_file,
                                                              corners_barrel_file)
                            print("Wrote files to", output_dir)

                            # mark this slice/loc already drawn 
                            already_drawn_slic_loc[str(slic_id)+"_"+str(loc_id)] = output_dir
                    image_data.clear()
# Out:
# 04_01_06
# 4 1
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [42, 46]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/
# 05_01_09
# 5 1
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [45, 44]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/
# 01_01_02
# 1 1
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [41, 42]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/
# 01_02_03
# 1 2
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [26, 37]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/
# 01_02_06
# 01_03_04
# 1 3
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [14, 37]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/
# 01_03_06
# 01_05_03
# 1 5
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [25, 54]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/
# 02_03_03
# 2 3
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [32, 58]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/
# 02_04_03
# 2 4
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [52, 48]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/
# 02_05_03
# 2 5
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [35, 40]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/
# 02_05_04
# 02_05_05
# 02_05_07
# 02_05_08
# 02_05_09
# 02_06_06
# 2 6
# Number of shapes drawn: 1
# Number of shapes drawn: 4
# Electrode point: [24, 33]
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/electrode.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/corners_layer.dat
# Regions written to: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/corners_barrel.dat
# Wrote files to C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/

# %%
current_color_bound_setting = 1.0
for subdir, dirs, files in os.walk(data_dir):
    if 'notUsable' in subdir:
        continue
    if 'mm_hidden' in subdir:
        continue
    if 'dic' in dirs and 'selected_zda' in dirs:
        print(subdir)
        dic_dir = subdir + "/dic/"
        selected_zda_dir = subdir + "/selected_zda/"

        for zda_file in os.listdir(selected_zda_dir):
            if zda_file.endswith('.zda'):

                rec_id = zda_file.split('.')[0]
                print(rec_id)
                # movie dir
                output_dir = selected_zda_dir + "/analysis" + rec_id + "/"
                try:
                    os.makedirs(output_dir)
                except Exception as e:
                    pass

                # determine if we are even missing any jpg'd frames
                need_to_open_zda = True
                for frame in range(start_frame, start_frame + movie_length):
                    filename = output_dir + str(frame) + ".jpg"
                    if not os.path.exists(filename):
                        need_to_open_zda = True
                        break
                if not need_to_open_zda and not replace_existing_frame_pngs:
                    continue

                recording_max_snr = 20.0  # gets changed

                if not disable_photoZ_interact:
                    aPhz = AutoPhotoZ(data_dir=selected_zda_dir)
                    # open the PhotoZ file
                    aPhz.select_PhotoZ()

                    print("\n\nOpening", zda_file)
                    aPhz.open_zda_file(selected_zda_dir + "/" + zda_file)

                    # estimate the SNR max across all frames
                    aPhz.set_measure_window(start_frame, movie_length)
                    filename = aPhz.save_background()
                    print("Saved intermed_snr_df file:", filename)
                    if filename is not None:  # otherwise, sticks with default rec max of 20

                        # open Data.dat and read in the array max
                        intermed_snr_df = pd.read_csv(filename, 
                                                      sep='\t', 
                                                      header=None, 
                                                      names=['Index',  'Values'])
                        recording_max_snr = intermed_snr_df['Values'].max()

                        recording_max_snr *= 1.05  # 5% higher for headroom
                        recording_max_snr = round(recording_max_snr, 2)
                        if clean_scratch_files:
                            try:
                                os.remove(filename)
                            except Exception as e:
                                print("Could not remove", filename)
                                print(e)

                    # set the normalization to be consistent across entire video
                    aPhz.set_color_upper_bound(recording_max_snr, current_color_bound_setting)
                    print("Moved color upper bound from", current_color_bound_setting, "to", recording_max_snr)
                    current_color_bound_setting = recording_max_snr

                    # set measure window width to 1
                    aPhz.set_measure_window(None, 1)

                ##### Get frame annotation: layer and stim markings, and store #####

                # file conventions across
                electrode_file = output_dir + "/electrode.dat"
                corners_layer_file = output_dir + "/corners_layer.dat"
                corners_barrel_file = output_dir + "/corners_barrel.dat"
                annotations_enabled = all([os.path.exists(f) for f in [electrode_file, 
                                                                       corners_layer_file, 
                                                                       corners_barrel_file]])

                def array_point_to_image_pixel(arr_pt):
                    x_arr, y_arr = arr_pt
                    return [image_border_width + image_scaling * x_arr, 
                            image_border_width + image_scaling * y_arr]

                if annotations_enabled:
                    # read in electrode location
                    with open(electrode_file, 'r') as f:
                        lines = f.readlines()
                    stim_pt = int(lines[-1]) # last line is always electrode location
                    aux_obj = LaminarROI([stim_pt]).get_points()
                    stim_pt = aux_obj[0]  # should be a list of len 2, representing px location [x, y]
                    print("Stim point:", stim_pt)
                    stim_img_px = array_point_to_image_pixel(stim_pt)
                    stim_xy = (stim_img_px[0] - electrode_marker_radius, 
                               stim_img_px[1] - electrode_marker_radius, 
                               stim_img_px[0] + electrode_marker_radius, 
                               stim_img_px[1] + electrode_marker_radius)
                    # read in corners files
                    la_corners = {corners_layer_file: {},
                                  corners_barrel_file: {}}
                    for la_file in [corners_layer_file, corners_barrel_file]:
                        with open(la_file, 'r') as f:
                            lines = f.readlines() 
                        corners = [int(x) for x in lines[4:]] # the last 4 lines are diode numbers of corners
                        layer_axes = LayerAxes(corners)
                        laminar_axis, laminar_axis_2 = layer_axes.get_layer_axes()
                        print("laminar axis unit vectors:", laminar_axis.get_unit_vector(), 
                              laminar_axis_2.get_unit_vector())

                        end = array_point_to_image_pixel(laminar_axis.get_end_point())
                        end2 = array_point_to_image_pixel(laminar_axis_2.get_end_point())
                        start = array_point_to_image_pixel(laminar_axis.get_start_point())
                        start2 = array_point_to_image_pixel(laminar_axis_2.get_start_point())
                        la_corners[la_file]["line_loc"] = [start + end, start2 + end2]
                        la_corners[la_file]["text_loc"] = (int((end[0] + end2[0]) / 2), 
                                                           int((end[1] + end2[1]) / 2))


                images = []
                img_filenames = []
                for frame in range(start_frame, start_frame + movie_length):
                    filename = output_dir + str(frame) + ".jpg"
                    if replace_existing_frame_pngs or not os.path.exists(filename):
                        # change frame
                        if not disable_photoZ_interact:
                            aPhz.set_measure_window(frame, None)

                            # export this frame
                            aPhz.save_map_jpeg(filename)
                            print("File created:", filename)

                    if annotations_enabled:
                        # draw electrode location on image <filename>
                        image = Image.open(filename)
                        draw = ImageDraw.Draw(image)
                        draw.ellipse(stim_xy, outline='red', width=2)
                        # read in corners files
                        for la_file in [corners_layer_file, corners_barrel_file]:
                            draw.line(la_corners[la_file]["line_loc"][0], fill='white', width=2)
                            draw.line(la_corners[la_file]["line_loc"][1], fill='white', width=2)
                            if la_file == corners_layer_file:
                                draw.text(la_corners[la_file]["text_loc"], "L4", anchor="ms")
                        # PIL image write back
                        image.save(filename)

                    try:
                        images.append(imageio.imread(filename))
                        img_filenames.append(filename)
                    except Exception as e:
                        pass

                # create gif
                created_movie = False
                try:
                    imageio.mimsave(output_dir + rec_id + 'movie.gif', images)
                    print("CREATED MOVIE:", rec_id + 'movie.gif')
                    created_movie = True
                    if clean_scratch_files:
                        for img_file in img_filenames:
                            os.remove(img_file)
                except Exception as e:
                    if not created_movie:
                        print("Not creating movie for " + rec_id)
                    print(e)
# Out:
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23
# 04_01_06
#
#
# Opening 04_01_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 1.0 to 6.94
# Stim point: [42, 46]
# edge_pts [[14, 69], [42, 70]] axis_pts [[8, 29], [24, 11]]
# laminar axis unit vectors: [0.14834045293024462, 0.9889363528682975] [0.2918066430898717, 0.9564773301279128]
# edge_pts [[78, 18], [76, 52]] axis_pts [[8, 33], [8, 51]]
# laminar axis unit vectors: [0.9778024140774095, -0.20952908873087348] [0.9998918860475786, 0.014704292441876156]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis04_01_06/120.jpg
# CREATED MOVIE: 04_01_06movie.gif
# 05_01_09
#
#
# Opening 05_01_09.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//Data.dat
# Moved color upper bound from 6.94 to 8.83
# Stim point: [45, 44]
# edge_pts [[77, 12], [77, 35]] axis_pts [[11, 34], [8, 52]]
# laminar axis unit vectors: [0.9486832980505138, -0.31622776601683794] [0.9709646117278029, -0.23922316520829925]
# edge_pts [[34, 70], [75, 59]] axis_pts [[23, 16], [52, 11]]
# laminar axis unit vectors: [0.19960448214422574, 0.9798765487080173] [0.4321201804305529, 0.9018160287246321]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/02-28-23/selected_zda//analysis05_01_09/120.jpg
# CREATED MOVIE: 05_01_09movie.gif
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23
# 01_01_02
#
#
# Opening 01_01_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.83 to 8.96
# Stim point: [41, 42]
# edge_pts [[76, 30], [76, 54]] axis_pts [[12, 23], [8, 45]]
# laminar axis unit vectors: [0.9940716917543756, 0.10872659128563483] [0.9913547659899606, 0.13120871902808304]
# edge_pts [[27, 8], [54, 10]] axis_pts [[21, 68], [48, 70]]
# laminar axis unit vectors: [0.09950371902099892, -0.9950371902099892] [0.09950371902099892, -0.9950371902099892]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_01_02/120.jpg
# CREATED MOVIE: 01_01_02movie.gif
# 01_02_03
#
#
# Opening 01_02_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.96 to 6.52
# Stim point: [26, 37]
# edge_pts [[76, 28], [75, 56]] axis_pts [[12, 19], [9, 48]]
# laminar axis unit vectors: [0.9902565788380345, 0.1392548313990986] [0.9927337820337083, 0.12033136751923737]
# edge_pts [[22, 70], [52, 72]] axis_pts [[27, 9], [56, 11]]
# laminar axis unit vectors: [-0.08169323944527151, 0.9966575212323125] [-0.06543324256067616, 0.9978569490503113]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_03/120.jpg
# CREATED MOVIE: 01_02_03movie.gif
# 01_02_06
#
#
# Opening 01_02_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 6.52 to 7.74
# Stim point: [26, 37]
# edge_pts [[76, 28], [75, 56]] axis_pts [[12, 19], [9, 48]]
# laminar axis unit vectors: [0.9902565788380345, 0.1392548313990986] [0.9927337820337083, 0.12033136751923737]
# edge_pts [[22, 70], [52, 72]] axis_pts [[27, 9], [56, 11]]
# laminar axis unit vectors: [-0.08169323944527151, 0.9966575212323125] [-0.06543324256067616, 0.9978569490503113]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_02_06/120.jpg
# CREATED MOVIE: 01_02_06movie.gif
# 01_03_04
#
#
# Opening 01_03_04.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 7.74 to 7.83
# Stim point: [14, 37]
# edge_pts [[77, 26], [75, 55]] axis_pts [[9, 15], [7, 47]]
# laminar axis unit vectors: [0.9871673987372203, 0.15968884391337385] [0.9931506043228762, 0.1168412475673972]
# edge_pts [[19, 70], [54, 72]] axis_pts [[25, 9], [57, 13]]
# laminar axis unit vectors: [-0.09788826992209926, 0.9951974108746757] [-0.05078185267991494, 0.9987097693716604]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_04/120.jpg
# CREATED MOVIE: 01_03_04movie.gif
# 01_03_06
#
#
# Opening 01_03_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 7.83 to 7.55
# Stim point: [14, 37]
# edge_pts [[77, 26], [75, 55]] axis_pts [[9, 15], [7, 47]]
# laminar axis unit vectors: [0.9871673987372203, 0.15968884391337385] [0.9931506043228762, 0.1168412475673972]
# edge_pts [[19, 70], [54, 72]] axis_pts [[25, 9], [57, 13]]
# laminar axis unit vectors: [-0.09788826992209926, 0.9951974108746757] [-0.05078185267991494, 0.9987097693716604]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_03_06/120.jpg
# CREATED MOVIE: 01_03_06movie.gif
# 01_05_03
#
#
# Opening 01_05_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 7.55 to 8.59
# Stim point: [25, 54]
# edge_pts [[77, 28], [76, 53]] axis_pts [[8, 18], [7, 48]]
# laminar axis unit vectors: [0.9896605990003554, 0.14342907231889207] [0.9973847959828921, 0.07227426057847045]
# edge_pts [[20, 70], [51, 72]] axis_pts [[29, 9], [59, 12]]
# laminar axis unit vectors: [-0.14596087331426824, 0.9892903635744847] [-0.13216372009101796, 0.9912279006826347]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis01_05_03/120.jpg
# CREATED MOVIE: 01_05_03movie.gif
# 02_03_03
#
#
# Opening 02_03_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.59 to 12.7
# Stim point: [32, 58]
# edge_pts [[77, 12], [76, 32]] axis_pts [[7, 59], [29, 67]]
# laminar axis unit vectors: [0.8302211308910923, -0.5574341878840191] [0.8020431103403957, -0.597266145998167]
# edge_pts [[7, 33], [30, 8]] axis_pts [[56, 66], [73, 47]]
# laminar axis unit vectors: [-0.8294369271052774, -0.5586003794790644] [-0.7407190347407712, -0.6718149384858157]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_03_03/120.jpg
# CREATED MOVIE: 02_03_03movie.gif
# 02_04_03
#
#
# Opening 02_04_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 12.7 to 6.68
# Stim point: [52, 48]
# edge_pts [[67, 11], [77, 32]] axis_pts [[8, 58], [36, 68]]
# laminar axis unit vectors: [0.7821604975557965, -0.623077006527499] [0.7514402250505251, -0.6598011732150952]
# edge_pts [[6, 44], [8, 16]] axis_pts [[60, 69], [72, 49]]
# laminar axis unit vectors: [-0.9074669071198412, -0.42012356811103757] [-0.8888031674084939, -0.45828913319500464]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_04_03/120.jpg
# CREATED MOVIE: 02_04_03movie.gif
# 02_05_03
#
#
# Opening 02_05_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 6.68 to 8.9
# Stim point: [35, 40]
# edge_pts [[63, 11], [78, 27]] axis_pts [[6, 60], [31, 68]]
# laminar axis unit vectors: [0.7583167199710229, -0.6518863031329846] [0.7535690571589674, -0.6573687519897374]
# edge_pts [[7, 46], [8, 19]] axis_pts [[65, 69], [74, 42]]
# laminar axis unit vectors: [-0.929577903322658, -0.36862572028312296] [-0.9443036133718997, -0.3290755016296014]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_03/120.jpg
# CREATED MOVIE: 02_05_03movie.gif
# 02_05_04
#
#
# Opening 02_05_04.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.9 to 8.07
# Stim point: [35, 40]
# edge_pts [[63, 11], [78, 27]] axis_pts [[6, 60], [31, 68]]
# laminar axis unit vectors: [0.7583167199710229, -0.6518863031329846] [0.7535690571589674, -0.6573687519897374]
# edge_pts [[7, 46], [8, 19]] axis_pts [[65, 69], [74, 42]]
# laminar axis unit vectors: [-0.929577903322658, -0.36862572028312296] [-0.9443036133718997, -0.3290755016296014]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_04/120.jpg
# CREATED MOVIE: 02_05_04movie.gif
# 02_05_05
#
#
# Opening 02_05_05.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.07 to 8.86
# Stim point: [35, 40]
# edge_pts [[63, 11], [78, 27]] axis_pts [[6, 60], [31, 68]]
# laminar axis unit vectors: [0.7583167199710229, -0.6518863031329846] [0.7535690571589674, -0.6573687519897374]
# edge_pts [[7, 46], [8, 19]] axis_pts [[65, 69], [74, 42]]
# laminar axis unit vectors: [-0.929577903322658, -0.36862572028312296] [-0.9443036133718997, -0.3290755016296014]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_05/120.jpg
# CREATED MOVIE: 02_05_05movie.gif
# 02_05_07
#
#
# Opening 02_05_07.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.86 to 8.5
# Stim point: [35, 40]
# edge_pts [[63, 11], [78, 27]] axis_pts [[6, 60], [31, 68]]
# laminar axis unit vectors: [0.7583167199710229, -0.6518863031329846] [0.7535690571589674, -0.6573687519897374]
# edge_pts [[7, 46], [8, 19]] axis_pts [[65, 69], [74, 42]]
# laminar axis unit vectors: [-0.929577903322658, -0.36862572028312296] [-0.9443036133718997, -0.3290755016296014]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_07/120.jpg
# CREATED MOVIE: 02_05_07movie.gif
# 02_05_08
#
#
# Opening 02_05_08.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.5 to 8.79
# Stim point: [35, 40]
# edge_pts [[63, 11], [78, 27]] axis_pts [[6, 60], [31, 68]]
# laminar axis unit vectors: [0.7583167199710229, -0.6518863031329846] [0.7535690571589674, -0.6573687519897374]
# edge_pts [[7, 46], [8, 19]] axis_pts [[65, 69], [74, 42]]
# laminar axis unit vectors: [-0.929577903322658, -0.36862572028312296] [-0.9443036133718997, -0.3290755016296014]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_08/120.jpg
# CREATED MOVIE: 02_05_08movie.gif
# 02_05_09
#
#
# Opening 02_05_09.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 8.79 to 10.98
# Stim point: [35, 40]
# edge_pts [[63, 11], [78, 27]] axis_pts [[6, 60], [31, 68]]
# laminar axis unit vectors: [0.7583167199710229, -0.6518863031329846] [0.7535690571589674, -0.6573687519897374]
# edge_pts [[7, 46], [8, 19]] axis_pts [[65, 69], [74, 42]]
# laminar axis unit vectors: [-0.929577903322658, -0.36862572028312296] [-0.9443036133718997, -0.3290755016296014]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_05_09/120.jpg
# CREATED MOVIE: 02_05_09movie.gif
# 02_06_06
#
#
# Opening 02_06_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//Data.dat
# Moved color upper bound from 10.98 to 6.86
# Stim point: [24, 33]
# edge_pts [[75, 11], [77, 39]] axis_pts [[7, 61], [35, 68]]
# laminar axis unit vectors: [0.8056510126494246, -0.5923904504775181] [0.8228969006024468, -0.5681907170826418]
# edge_pts [[6, 42], [8, 16]] axis_pts [[64, 69], [75, 42]]
# laminar axis unit vectors: [-0.9065820610798456, -0.4220295801578592] [-0.932265558018721, -0.3617746941565186]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/06-09-23/selected_zda//analysis02_06_06/120.jpg
# CREATED MOVIE: 02_06_06movie.gif
