# %%
import time
import os
import math
import numpy as np
import cv2
import pandas as pd
import pyautogui as pa
import shutil
import imageio
from PIL import Image, ImageDraw

from lib.auto_GUI.auto_GUI_base import AutoGUIBase
from lib.auto_GUI.auto_DAT import AutoDAT
from lib.auto_GUI.auto_PhotoZ import AutoPhotoZ
from lib.analysis.laminar_dist import *
from lib.file.TIF import *
from lib.analysis.align import ImageAlign
from lib.utilities import *

# %%
# Make a series of 1-frame measure windows from PhotoZ

# Load data, not from Drive for Desktop since PhotoZ complains about loading zda from Drive
google_drive_dir = "G:/.shortcut-targets-by-id/1afwzLrN3AQQPbJ1PQiZlKAb1Bijc5qln/Choosing trajectories/"
data_dir = "C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/"
start_frame = 94
movie_length = 27
camera_program = 4

# annotation settings
skip_draw_annotations = True  # don't draw any new annotations

# Movie maker settings
disable_photoZ_interact = False
disable_google_drive_interact = True
initialize_photoZ = False
clean_scratch_files = False  # clean up SNR maps
replace_existing_frame_pngs = True
image_border_width = 8
image_scaling = 7  # pixels of image per array diode pixel
electrode_marker_radius = 4

# %%
# set up PhotoZ (open it manually)
aPhz = AutoPhotoZ(data_dir=data_dir)
if initialize_photoZ and not disable_photoZ_interact:
    aPhz.prepare_photoZ()
if not disable_photoZ_interact:
    aPhz.click_normalize_2_array_max()
pa.alert("Please disable trace overlay and maximize PhotoZ before continuing.")
# Out:
# 'OK'

# %%
# First ask user to annotate some images with Electrode loc and L4 boundaries and layer text placement
# based on DIC-to-ZDA_Alignment script
if not skip_draw_annotations:
    for subdir, dirs, files in os.walk(data_dir):
        if 'notUsable' in subdir:
            continue
        if 'mm_hidden' in subdir:
            continue
        if 'dic' in dirs and 'selected_zda' in dirs:
            dic_dir = subdir + "/dic/"
            selected_zda_dir = subdir + "/selected_zda/"
            already_drawn_slic_loc = {}

            # take selected zda and expand into separate subdir for each zda file
            for zda_file in os.listdir(selected_zda_dir):
                if zda_file.endswith('.zda'):
                    rec_id = zda_file.split('.')[0]
                    slic_id, loc_id, _ = [int(x) for x in rec_id.split("_")]
                    print(rec_id)
                    # output dir
                    output_dir = selected_zda_dir + "/analysis" + rec_id + "/"
                    try:
                        os.makedirs(output_dir)
                    except Exception as e:
                        pass

                    # read in 8-bit single TIF images to array, apply same cropping/binning
                    image_data = {}
                    cam_settings = CameraSettings().get_program_settings(camera_program)
                    binning = int(2048 / 400) # if want size similar to RLI
                    TIFLoader(dic_dir, 
                              cam_settings, 
                              binning, 
                              crop=False, 
                              flip_horiz=True).load_files(image_data, slice_target=slic_id)

                    # align RLI and DIC and record the RLI's image boundaries within the DIC image.
                    dic_coordinates = [[8, 6], [80, 12], [2, 69], [76, 74]]
                    img_aligner = ImageAlign(dic_coordinates)

                    for slic in image_data:
                        for loc in image_data[slic]:

                            if slic != slic_id or loc != loc_id:
                                continue

                            # if already drawn, no need to ask user again
                            if str(slic_id)+"_"+str(loc_id) in already_drawn_slic_loc:
                                # just copy them over
                                src_dir = already_drawn_slic_loc[str(slic_id)+"_"+str(loc_id)]
                                electrode_file = src_dir + "electrode.dat"
                                corners_layer_file = src_dir + "corners_layer.dat"
                                corners_barrel_file = src_dir + "corners_barrel.dat"
                                shutil.copy(electrode_file, output_dir + "electrode.dat")
                                shutil.copy(corners_layer_file, output_dir + "corners_layer.dat")
                                shutil.copy(corners_barrel_file, output_dir + "corners_barrel.dat")
                                continue

                            print(slic, loc)

                            # DICs
                            fluor = None
                            if 'f' in image_data[slic][loc]:
                                fluor = image_data[slic][loc]['f']
                            elif 'fe' in image_data[slic][loc]:
                                fluor = image_data[slic][loc]['fe']
                            # img = image_data[slic][loc]['i']

                            dic_electrode = None
                            if 'e' in image_data[slic][loc]:
                                dic_electrode = image_data[slic][loc]['e']
                            else:
                                dic_electrode = fluor

                            dic_electrode = np.array(dic_electrode, dtype=np.uint8)
                            orig_arr_shape = dic_electrode.shape

                            # ask user to select site of stim and layer/barrel borders
                            try:
                                dic_electrode, coords_electrode, dic_layers, coords_layers = img_aligner.draw_on_images_wrapper(dic_electrode, fluor)
                            except Exception as e:
                                print("User error in drawing.")
                                print(e)
                                continue
                            dic_electrode = np.array(dic_electrode)
                            dic_layers = np.array(dic_layers)

                            plt.imshow(dic_electrode, cmap='gray')
                            x_el, y_el = coords_electrode['electrode']
                            plt.plot(x_el, y_el, marker="*", color='red')
                            plt.show()
                            
                            plt.imshow(dic_layers, cmap='gray')
                            for pt in coords_layers['layer_axis1'] + coords_layers['layer_axis2'] + coords_layers['barrel_axis1'] + coords_layers['barrel_axis2']:
                                x, y = pt
                                plt.plot(x, y, marker="*", color='green')
                            plt.show()

                            try:
                                os.makedirs(output_dir)
                            except OSError:
                                pass

                            # transform coordinates -- Actual alignment work done here
                            coords_electrode = img_aligner.transform_from_dic_coordinates(coords_electrode, orig_arr_shape)
                            coords_layers = img_aligner.transform_from_dic_coordinates(coords_layers, orig_arr_shape)
                            coordinates = coords_electrode | coords_layers

                            # write to file
                            electrode_file = output_dir + "electrode.dat"
                            corners_layer_file = output_dir + "corners_layer.dat"
                            corners_barrel_file = output_dir + "corners_barrel.dat"
                            img_aligner.write_shapes_to_files(coordinates,
                                                              electrode_file,
                                                              corners_layer_file,
                                                              corners_barrel_file)
                            print("Wrote files to", output_dir)

                            # mark this slice/loc already drawn 
                            already_drawn_slic_loc[str(slic_id)+"_"+str(loc_id)] = output_dir
                    image_data.clear()

# %%
current_color_bound_setting = 1.0
for subdir, dirs, files in os.walk(data_dir):
    if 'notUsable' in subdir:
        continue
    if 'mm_hidden' in subdir:
        continue
    if 'dic' in dirs and 'selected_zda' in dirs:
        print(subdir)
        dic_dir = subdir + "/dic/"
        selected_zda_dir = subdir + "/selected_zda/"

        for zda_file in os.listdir(selected_zda_dir):
            if zda_file.endswith('.zda'):

                rec_id = zda_file.split('.')[0]
                print(rec_id)
                # movie dir
                output_dir = selected_zda_dir + "/analysis" + rec_id + "/"
                try:
                    os.makedirs(output_dir)
                except Exception as e:
                    pass

                # determine if we are even missing any jpg'd frames
                need_to_open_zda = True
                for frame in range(start_frame, start_frame + movie_length):
                    filename = output_dir + str(frame) + ".jpg"
                    if not os.path.exists(filename):
                        need_to_open_zda = True
                        break
                if not need_to_open_zda and not replace_existing_frame_pngs:
                    continue

                recording_max_snr = 20.0  # gets changed

                if not disable_photoZ_interact:
                    aPhz = AutoPhotoZ(data_dir=selected_zda_dir)
                    # open the PhotoZ file
                    aPhz.select_PhotoZ()

                    print("\n\nOpening", zda_file)
                    aPhz.open_zda_file(selected_zda_dir + "/" + zda_file)

                    # estimate the SNR max across all frames
                    aPhz.set_measure_window(start_frame, movie_length)
                    filename = aPhz.save_background()
                    print("Saved intermed_snr_df file:", filename)
                    if filename is not None:  # otherwise, sticks with default rec max of 20

                        # open Data.dat and read in the array max
                        intermed_snr_df = pd.read_csv(filename, 
                                                      sep='\t', 
                                                      header=None, 
                                                      names=['Index',  'Values'])
                        recording_max_snr = intermed_snr_df['Values'].max()

                        recording_max_snr *= 1.05  # 5% higher for headroom
                        recording_max_snr = round(recording_max_snr, 2)
                        if clean_scratch_files:
                            try:
                                os.remove(filename)
                            except Exception as e:
                                print("Could not remove", filename)
                                print(e)

                    # set the normalization to be consistent across entire video
                    aPhz.set_color_upper_bound(recording_max_snr, current_color_bound_setting)
                    print("Moved color upper bound from", current_color_bound_setting, "to", recording_max_snr)
                    current_color_bound_setting = recording_max_snr

                    # set measure window width to 1
                    aPhz.set_measure_window(None, 1)

                ##### Get frame annotation: layer and stim markings, and store #####

                # file conventions across
                electrode_file = output_dir + "/electrode.dat"
                corners_layer_file = output_dir + "/corners_layer.dat"
                corners_barrel_file = output_dir + "/corners_barrel.dat"
                annotations_enabled = all([os.path.exists(f) for f in [electrode_file, 
                                                                       corners_layer_file, 
                                                                       corners_barrel_file]])

                def array_point_to_image_pixel(arr_pt):
                    x_arr, y_arr = arr_pt
                    return [image_border_width + image_scaling * x_arr, 
                            image_border_width + image_scaling * y_arr]

                if annotations_enabled:
                    # read in electrode location
                    with open(electrode_file, 'r') as f:
                        lines = f.readlines()
                    stim_pt = int(lines[-1]) # last line is always electrode location
                    aux_obj = LaminarROI([stim_pt]).get_points()
                    stim_pt = aux_obj[0]  # should be a list of len 2, representing px location [x, y]
                    print("Stim point:", stim_pt)
                    stim_img_px = array_point_to_image_pixel(stim_pt)
                    stim_xy = (stim_img_px[0] - electrode_marker_radius, 
                               stim_img_px[1] - electrode_marker_radius, 
                               stim_img_px[0] + electrode_marker_radius, 
                               stim_img_px[1] + electrode_marker_radius)
                    # read in corners files
                    la_corners = {corners_layer_file: {},
                                  corners_barrel_file: {}}
                    for la_file in [corners_layer_file, corners_barrel_file]:
                        with open(la_file, 'r') as f:
                            lines = f.readlines() 
                        corners = [int(x) for x in lines[4:]] # the last 4 lines are diode numbers of corners
                        layer_axes = LayerAxes(corners)
                        laminar_axis, laminar_axis_2 = layer_axes.get_layer_axes()
                        print("laminar axis unit vectors:", laminar_axis.get_unit_vector(), 
                              laminar_axis_2.get_unit_vector())

                        end = array_point_to_image_pixel(laminar_axis.get_end_point())
                        end2 = array_point_to_image_pixel(laminar_axis_2.get_end_point())
                        start = array_point_to_image_pixel(laminar_axis.get_start_point())
                        start2 = array_point_to_image_pixel(laminar_axis_2.get_start_point())
                        la_corners[la_file]["line_loc"] = [start + end, start2 + end2]
                        la_corners[la_file]["text_loc"] = (int((end[0] + end2[0]) / 2), 
                                                           int((end[1] + end2[1]) / 2))


                images = []
                img_filenames = []
                for frame in range(start_frame, start_frame + movie_length):
                    filename = output_dir + str(frame) + ".jpg"
                    if replace_existing_frame_pngs or not os.path.exists(filename):
                        # change frame
                        if not disable_photoZ_interact:
                            aPhz.set_measure_window(frame, None)

                            # export this frame
                            aPhz.save_map_jpeg(filename)
                            print("File created:", filename)

                    if annotations_enabled:
                        # draw electrode location on image <filename>
                        image = Image.open(filename)
                        draw = ImageDraw.Draw(image)
                        draw.ellipse(stim_xy, outline='red', width=2)
                        # read in corners files
                        for la_file in [corners_layer_file, corners_barrel_file]:
                            draw.line(la_corners[la_file]["line_loc"][0], fill='white', width=2)
                            draw.line(la_corners[la_file]["line_loc"][1], fill='white', width=2)
                            if la_file == corners_layer_file:
                                draw.text(la_corners[la_file]["text_loc"], "L4", anchor="ms")
                        # PIL image write back
                        image.save(filename)

                    try:
                        images.append(imageio.imread(filename))
                        img_filenames.append(filename)
                    except Exception as e:
                        pass

                # create gif
                created_movie = False
                try:
                    imageio.mimsave(output_dir + rec_id + 'movie.gif', images)
                    print("CREATED MOVIE:", rec_id + 'movie.gif')
                    created_movie = True
                    if clean_scratch_files:
                        for img_file in img_filenames:
                            os.remove(img_file)
                except Exception as e:
                    if not created_movie:
                        print("Not creating movie for " + rec_id)
                    print(e)
# Out:
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-07-23
# C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23
# 02_01_01
#
#
# Opening 02_01_01.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 1.0 to 9.81
# Stim point: [54, 25]
# edge_pts [[75, 57], [52, 72]] axis_pts [[16, 9], [8, 34]]
# laminar axis unit vectors: [0.7757116786991037, 0.63108746741622] [0.7568230077691596, 0.6536198703460924]
# edge_pts [[51, 9], [77, 28]] axis_pts [[11, 40], [32, 68]]
# laminar axis unit vectors: [0.7904150521752438, -0.612571665435814] [0.7474093186836598, -0.6643638388299198]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_01/120.jpg
# CREATED MOVIE: 02_01_01movie.gif
# 02_01_04
#
#
# Opening 02_01_04.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 9.81 to 10.91
# Stim point: [54, 25]
# edge_pts [[75, 57], [52, 72]] axis_pts [[16, 9], [8, 34]]
# laminar axis unit vectors: [0.7757116786991037, 0.63108746741622] [0.7568230077691596, 0.6536198703460924]
# edge_pts [[51, 9], [77, 28]] axis_pts [[11, 40], [32, 68]]
# laminar axis unit vectors: [0.7904150521752438, -0.612571665435814] [0.7474093186836598, -0.6643638388299198]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_04/120.jpg
# CREATED MOVIE: 02_01_04movie.gif
# 02_01_06
#
#
# Opening 02_01_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 10.91 to 7.97
# Stim point: [54, 25]
# edge_pts [[75, 57], [52, 72]] axis_pts [[16, 9], [8, 34]]
# laminar axis unit vectors: [0.7757116786991037, 0.63108746741622] [0.7568230077691596, 0.6536198703460924]
# edge_pts [[51, 9], [77, 28]] axis_pts [[11, 40], [32, 68]]
# laminar axis unit vectors: [0.7904150521752438, -0.612571665435814] [0.7474093186836598, -0.6643638388299198]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_01_06/120.jpg
# CREATED MOVIE: 02_01_06movie.gif
# 02_02_03
#
#
# Opening 02_02_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 7.97 to 11.61
# Stim point: [41, 43]
# edge_pts [[75, 60], [48, 72]] axis_pts [[18, 8], [8, 31]]
# laminar axis unit vectors: [0.738766024783967, 0.6739619875222155] [0.6983238520753277, 0.7157819483772108]
# edge_pts [[6, 41], [23, 70]] axis_pts [[54, 11], [76, 34]]
# laminar axis unit vectors: [-0.847998304005088, 0.52999894000318] [-0.827216691275022, 0.5618830355830338]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_02_03/120.jpg
# CREATED MOVIE: 02_02_03movie.gif
# 02_03_02
#
#
# Opening 02_03_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 11.61 to 12.23
# Stim point: [63, 62]
# edge_pts [[73, 59], [42, 71]] axis_pts [[19, 8], [9, 33]]
# laminar axis unit vectors: [0.7270131525498175, 0.6866235329637166] [0.655686655446243, 0.7550331183926435]
# edge_pts [[24, 69], [67, 73]] axis_pts [[74, 28], [73, 70]]
# laminar axis unit vectors: [-0.7732677904963985, 0.6340795882070467] [-0.8944271909999159, 0.4472135954999579]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_03_02/120.jpg
# CREATED MOVIE: 02_03_02movie.gif
# 02_04_02
#
#
# Opening 02_04_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 12.23 to 12.48
# Stim point: [19, 18]
# edge_pts [[75, 67], [52, 73]] axis_pts [[14, 7], [7, 33]]
# laminar axis unit vectors: [0.7129262923855025, 0.7012389761168877] [0.7474093186836598, 0.6643638388299198]
# edge_pts [[6, 43], [8, 9]] axis_pts [[62, 13], [14, 7]]
# laminar axis unit vectors: [-0.8814799700287821, 0.472221412515419] [-0.9486832980505138, 0.31622776601683794]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_04_02/120.jpg
# CREATED MOVIE: 02_04_02movie.gif
# 02_06_01
#
#
# Opening 02_06_01.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 12.48 to 8.88
# Stim point: [56, 34]
# edge_pts [[75, 60], [49, 72]] axis_pts [[25, 8], [7, 29]]
# laminar axis unit vectors: [0.6931087162517846, 0.720833064901856] [0.6987395238751688, 0.7153761792055299]
# edge_pts [[5, 51], [29, 70]] axis_pts [[60, 11], [71, 41]]
# laminar axis unit vectors: [-0.8087360843031886, 0.5881716976750462] [-0.8228969006024468, 0.5681907170826418]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_01/120.jpg
# CREATED MOVIE: 02_06_01movie.gif
# 02_06_05
#
#
# Opening 02_06_05.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 8.88 to 11.12
# Stim point: [56, 34]
# edge_pts [[75, 60], [49, 72]] axis_pts [[25, 8], [7, 29]]
# laminar axis unit vectors: [0.6931087162517846, 0.720833064901856] [0.6987395238751688, 0.7153761792055299]
# edge_pts [[5, 51], [29, 70]] axis_pts [[60, 11], [71, 41]]
# laminar axis unit vectors: [-0.8087360843031886, 0.5881716976750462] [-0.8228969006024468, 0.5681907170826418]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_05/120.jpg
# CREATED MOVIE: 02_06_05movie.gif
# 02_06_06
#
#
# Opening 02_06_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 11.12 to 10.01
# Stim point: [56, 34]
# edge_pts [[75, 60], [49, 72]] axis_pts [[25, 8], [7, 29]]
# laminar axis unit vectors: [0.6931087162517846, 0.720833064901856] [0.6987395238751688, 0.7153761792055299]
# edge_pts [[5, 51], [29, 70]] axis_pts [[60, 11], [71, 41]]
# laminar axis unit vectors: [-0.8087360843031886, 0.5881716976750462] [-0.8228969006024468, 0.5681907170826418]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis02_06_06/120.jpg
# CREATED MOVIE: 02_06_06movie.gif
# 03_01_03
#
#
# Opening 03_01_03.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 10.01 to 15.76
# Stim point: [43, 22]
# edge_pts [[76, 32], [73, 61]] axis_pts [[8, 31], [8, 60]]
# laminar axis unit vectors: [0.9998918860475786, 0.014704292441876156] [0.999881677808259, 0.015382795043203983]
# edge_pts [[26, 8], [52, 10]] axis_pts [[18, 68], [56, 69]]
# laminar axis unit vectors: [0.13216372009101796, -0.9912279006826347] [-0.06764133573679162, -0.9977097021176764]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_03/120.jpg
# CREATED MOVIE: 03_01_03movie.gif
# 03_01_05
#
#
# Opening 03_01_05.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 15.76 to 16.72
# Stim point: [43, 22]
# edge_pts [[76, 32], [73, 61]] axis_pts [[8, 31], [8, 60]]
# laminar axis unit vectors: [0.9998918860475786, 0.014704292441876156] [0.999881677808259, 0.015382795043203983]
# edge_pts [[26, 8], [52, 10]] axis_pts [[18, 68], [56, 69]]
# laminar axis unit vectors: [0.13216372009101796, -0.9912279006826347] [-0.06764133573679162, -0.9977097021176764]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_05/120.jpg
# CREATED MOVIE: 03_01_05movie.gif
# 03_01_08
#
#
# Opening 03_01_08.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 16.72 to 15.87
# Stim point: [43, 22]
# edge_pts [[76, 32], [73, 61]] axis_pts [[8, 31], [8, 60]]
# laminar axis unit vectors: [0.9998918860475786, 0.014704292441876156] [0.999881677808259, 0.015382795043203983]
# edge_pts [[26, 8], [52, 10]] axis_pts [[18, 68], [56, 69]]
# laminar axis unit vectors: [0.13216372009101796, -0.9912279006826347] [-0.06764133573679162, -0.9977097021176764]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_01_08/120.jpg
# CREATED MOVIE: 03_01_08movie.gif
# 03_04_02
#
#
# Opening 03_04_02.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 15.87 to 16.9
# Stim point: [46, 71]
# edge_pts [[75, 44], [75, 68]] axis_pts [[8, 36], [7, 63]]
# laminar axis unit vectors: [0.9929467931694284, 0.11856081112470786] [0.9973076252903365, 0.07333144303605414]
# edge_pts [[38, 9], [76, 11]] axis_pts [[29, 65], [73, 66]]
# laminar axis unit vectors: [0.15867809538375516, -0.9873303712766988] [0.054464493159869794, -0.9985157079309461]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_02/120.jpg
# CREATED MOVIE: 03_04_02movie.gif
# 03_04_06
#
#
# Opening 03_04_06.zda
# Saved intermed_snr_df file: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//Data.dat
# Moved color upper bound from 16.9 to 15.27
# Stim point: [46, 71]
# edge_pts [[75, 44], [75, 68]] axis_pts [[8, 36], [7, 63]]
# laminar axis unit vectors: [0.9929467931694284, 0.11856081112470786] [0.9973076252903365, 0.07333144303605414]
# edge_pts [[38, 9], [76, 11]] axis_pts [[29, 65], [73, 66]]
# laminar axis unit vectors: [0.15867809538375516, -0.9873303712766988] [0.054464493159869794, -0.9985157079309461]
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/94.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/95.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/96.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/97.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/98.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/99.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/100.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/101.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/102.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/103.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/104.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/105.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/106.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/107.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/108.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/109.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/110.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/111.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/112.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/113.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/114.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/115.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/116.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/117.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/118.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/119.jpg
# File created: C:/Users/jjudge3/Desktop/Data/mm_full_pipeline_targets/03-15-23/selected_zda//analysis03_04_06/120.jpg
# CREATED MOVIE: 03_04_06movie.gif

# %%
# copying movies into Google Drive
if not disable_google_drive_interact:
    for subdir, dirs, files in os.walk(data_dir):
        if 'notUsable' in subdir:
            continue
        if 'mm_hidden' in subdir:
            continue
            
        extend = subdir.split("movie_targets/")[-1]
        if "movie" in extend:
            
            dst_dir = google_drive_dir + extend
            if os.path.exists(dst_dir):
                try:
                    shutil.rmtree(dst_dir, ignore_errors=False, onerror=None)
                except Exception as e:
                    print("Dest dir", dst_dir, "not deleted. Skipping.")
                    print(e)
                    continue

            print(subdir, "\n", dst_dir, "\n\n")
            shutil.copytree(subdir, dst_dir)

# %%
# clean up local drive
if not disable_google_drive_interact:
    for subdir, dirs, files in os.walk(data_dir):
        if 'notUsable' in subdir:
            continue

        if "movie" in subdir:
            try:
                shutil.rmtree(subdir, ignore_errors=False, onerror=None)
            except Exception as e:
                print("Dir", subdir, "not deleted. Skipping.")
                print(e)
                continue

            print("Deleted:", subdir)
