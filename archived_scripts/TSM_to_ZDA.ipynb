# %%
from lib.controller import Controller
from lib.automation import FileDetector
import time
import os

# %%
# Commonly changed settings

new_rig_settings = True
datadir = "./tsm_targets/05-31-22" # All files in this directory + subdirectories are loaded
if new_rig_settings:
    datadir = None # auto selects "C:/Turbo-SM/SMDATA/John/mm-dd-yy" on new rig
n_group_by_trials = 5 # Treats every n selected files as trials to combine into single ZDA file

c = Controller(camera_program=4,
              new_rig_settings=new_rig_settings,
              should_auto_launch=False,  # set to False as a safety to avoid double-launch
              datadir=datadir)
print("Data exchange directory:", c.get_data_dir())
# Out:
# Data exchange directory: C:/Turbo-SM/SMDATA/John/06-15-22

# %%
c.start_up(force_launch=False) # launch and orchestrate
slice_no = 4
location_no = 1
recording_no = 1
detection_loops = 1

# %%
# auto mode: TSM scheduling
c = Controller(camera_program=4,
              new_rig_settings=new_rig_settings,
              should_auto_launch=False,
              datadir=datadir,  
              filename_PhotoZ_format=True)  # SS_LL_RR.zda naming
c.run_recording_schedule(number_of_recordings=1)  # default: takes 5 trials at 15-s intervals

# %%
new_files = []
# archive directory
dst_dir = c.get_data_dir() + "/" + str(slice_no) + "_" + str(location_no)
if not os.path.exists(dst_dir):
    os.makedirs(dst_dir)
    
fd = FileDetector(directory=c.get_data_dir())
for i in range(detection_loops):
    time.sleep(3)
    fd.detect_files()
    new_files += fd.get_unprocessed_file_list()
    if len(new_files) >= n_group_by_trials:
        new_files.sort()
        print("Preparing to process into ZDA file(s)... ")
        time.sleep(5)  # wait for TurboSM to safely finish writing to disk
        
        # process new files
        n_process = len(new_files) - (len(new_files) % n_group_by_trials)
        c.select_files(selected_filenames=new_files[:n_process],
                       slice_no=slice_no,
                       location_no=location_no,
                       recording_no=recording_no)
        c.process_files(n_group_by_trials=n_group_by_trials)
        recording_no += int(len(new_files) / n_group_by_trials)
        
        # auto-archive processed files by moving them to a directory 'slice-loc'
        for pro_file in new_files[:n_process]:
            stripped_file = pro_file.split("/")[-1]
            dst_file = dst_dir + "/" + stripped_file
            os.rename(pro_file, dst_file)
            # tbn file
            os.rename(pro_file[:-4] + ".tbn", dst_file[:-4] + ".tbn")

        
        new_files = new_files[n_process:]
    print("Next recording_no:", recording_no)
    print(new_files)
# Out:
# New file detected: Untitled041.tsm
# New file detected: Untitled042.tsm
# New file detected: Untitled043.tsm
# New file detected: Untitled044.tsm
# New file detected: Untitled045.tsm
# Preparing to process into ZDA file(s)...
# C:/Turbo-SM/SMDATA/John/06-15-22/Untitled041.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22/Untitled042.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22/Untitled043.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22/Untitled044.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22/Untitled045.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled011.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled012.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled013.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled014.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled015.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled016.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled017.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled018.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled019.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled020.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled021.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled022.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled023.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled024.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled025.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled026.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled027.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled028.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled029.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\2_1/Untitled030.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled001.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled002.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled003.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled004.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled005.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled006.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled007.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled008.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled009.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\3_1/Untitled010.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled031.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled032.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled033.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled034.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled035.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled036.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled037.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled038.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled039.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# C:/Turbo-SM/SMDATA/John/06-15-22\4_1/Untitled040.tsm to be treated as TSM file to open
# Reading file as 200 images of size 512 x 160
# TBN file designates origin as NI for this data.
# Found 4 channels in BNC ratio: 1
# {'points_per_trace': 200, 'raw_width': 512, 'raw_height': 160, 'interval_between_samples': 0.5, 'number_of_trials': 1}
# 45 files loaded.
# # datasets to analyze: 5
# Discarding last 0 files.
# New # datasets to analyze: 5
# {'points_per_trace': 199, 'raw_width': 199, 'raw_height': -40, 'interval_between_samples': 0.5, 'number_of_trials': 1} (1, 199, 159, 160)
# {'points_per_trace': 199, 'raw_width': 199, 'raw_height': -40, 'interval_between_samples': 0.5, 'number_of_trials': 1} (1, 199, 159, 160)
# {'points_per_trace': 199, 'raw_width': 199, 'raw_height': -40, 'interval_between_samples': 0.5, 'number_of_trials': 1} (1, 199, 159, 160)
# {'points_per_trace': 199, 'raw_width': 199, 'raw_height': -40, 'interval_between_samples': 0.5, 'number_of_trials': 1} (1, 199, 159, 160)
# {'points_per_trace': 199, 'raw_width': 199, 'raw_height': -40, 'interval_between_samples': 0.5, 'number_of_trials': 1} (1, 199, 159, 160)
# (1, 199, 80, 80)
# (1, 8, 199)
# trial group 0
# 	 C:/Turbo-SM/SMDATA/John/06-15-22/Untitled041.tsm
# 	 C:/Turbo-SM/SMDATA/John/06-15-22/Untitled042.tsm
# 	 C:/Turbo-SM/SMDATA/John/06-15-22/Untitled043.tsm
# 	 C:/Turbo-SM/SMDATA/John/06-15-22/Untitled044.tsm
# 	 C:/Turbo-SM/SMDATA/John/06-15-22/Untitled045.tsm
# # of trial-grouped datasets: 1
# Not all DLL search paths added.
# (5, 8, 199)
# Written to 04_01_03.zda
# Next recording_no: 4
# []

# %%
# manual mode example: processing only
""" c.select_files(slice_no=3, 
                   location_no=1,
                   recording_no=1, 
                   filename_base="3-1-",
                   filename_start_no=1,
                   filename_end_no=25)
c.process_files(n_group_by_trials=n_group_by_trials) """

# %% [raw]
# #
